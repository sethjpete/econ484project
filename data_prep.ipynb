# %%
import pandas as pd
import math

# %%
def process_isbn(isbn):
    if type(isbn) == float:
        isbn = str(isbn)
    if len(isbn) != 10:
        isbn = '0'*(10-len(isbn)) + isbn
    assert len(isbn) == 10
    isbn = str(isbn)[:-1]
    isbn = isbn[3:]
    try:
        int(isbn)
    except:
        print('err', isbn)
    return isbn

# %%
df1 = pd.read_csv('dylancastillo/books.csv', usecols = ['isbn10', 'description', 'categories'])
df1.columns = ['isbn', 'description', 'categories']
df1['isbn'] = df1['isbn'].apply(process_isbn)
print(len(df1))
df1.head(3)
# Out:
# 6810
#      isbn                    description
# 0  200588                        Fiction  \
# 1  226198  Detective and mystery stories
# 2  616383               American fiction
#
#                                           categories
# 0  A NOVEL THAT READERS and critics have been eag...
# 1  A new 'Christie for Christmas' -- a full-lengt...
# 2  Volume Two of Stephen Donaldson's acclaimed se...

# %% [markdown]
# The last digit of the 10-digit ISBN is a checksum. We will drop it.

# %%
df2 = pd.read_csv('GoodReads/books.csv', index_col=0)
df2 = df2.drop(['isbn13', 'language_code'], axis=1)
df2['isbn'] = df2['isbn'].apply(process_isbn)
print(len(df2))
df2.head(3)
# Out:
# 11127
#                                                     title
# bookID
# 1       Harry Potter and the Half-Blood Prince (Harry ...  \
# 2       Harry Potter and the Order of the Phoenix (Har...
# 4       Harry Potter and the Chamber of Secrets (Harry...
#
#                            authors  average_rating    isbn  num_pages
# bookID
# 1       J.K. Rowling/Mary GrandPré            4.57  978596        652  \
# 2       J.K. Rowling/Mary GrandPré            4.49  935807        870
# 4                     J.K. Rowling            4.42  955489        352
#
#         ratings_count  text_reviews_count publication_date        publisher
# bookID
# 1             2095690               27591        9/16/2006  Scholastic Inc.
# 2             2153167               29221         9/1/2004  Scholastic Inc.
# 4                6333                 244        11/1/2003       Scholastic

# %%
df = pd.merge(df1, df2, on='isbn', how='right')

# %%
# Import bestseller data
bestsellers = pd.read_csv('NYTBest/bestsellers.csv')
bestsellers = bestsellers[['isbn10', 'rank', 'price', 'weeks_on_list', 'title', 'description', 'published_date']]
bestsellers.columns = ['isbn', 'rank', 'price', 'weeks_on_list', 'title', 'description', 'published_date']
# Must have an ISBN to enter this ride
bestsellers = bestsellers.dropna(subset=['isbn'])
bestsellers = bestsellers[~bestsellers['isbn'].str.startswith('isbn10 mu')]
# Convert ISBN to 9 digit standard we expect
bestsellers['isbn'] = bestsellers['isbn'].apply(process_isbn)
bestsellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 57975 entries, 0 to 61429
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   isbn            57975 non-null  object
#  1   rank            57975 non-null  int64
#  2   price           57975 non-null  float64
#  3   weeks_on_list   57975 non-null  int64
#  4   title           57975 non-null  object
#  5   description     50288 non-null  object
#  6   published_date  57975 non-null  object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 3.5+ MB

# %%
bestsellers = bestsellers.sort_values(by='weeks_on_list', ascending=False)
bestsellers['published_date'] = pd.to_datetime(bestsellers['published_date'])
bestsellers = bestsellers.drop_duplicates(subset='isbn', keep='first').reset_index(drop = True)
bestsellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8081 entries, 0 to 8080
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   isbn            8081 non-null   object
#  1   rank            8081 non-null   int64
#  2   price           8081 non-null   float64
#  3   weeks_on_list   8081 non-null   int64
#  4   title           8081 non-null   object
#  5   description     7410 non-null   object
#  6   published_date  8081 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 442.1+ KB

# %%
set(bestsellers['isbn']).intersection(set(df2['isbn']))
# Out:
# {'003205',
#  '003341',
#  '004360',
#  '010583',
#  '011440',
#  '024560',
#  '027633',
#  '027634',
#  '028923',
#  '033051',
#  '046209',
#  '083865',
#  '089922',
#  '102031',
#  '112241',
#  '116925',
#  '120752',
#  '122565',
#  '123822',
#  '124189',
#  '141707',
#  '152930',
#  '153009',
#  '153311',
#  '153513',
#  '153514',
#  '154174',
#  '154291',
#  '155548',
#  '161875',
#  '171825',
#  '179280',
#  '188394',
#  '195717',
#  '195795',
#  '207320',
#  '215216',
#  '215711',
#  '221720',
#  '221904',
#  '227083',
#  '228068',
#  '232119',
#  '236061',
#  '240612',
#  '240619',
#  '240698',
#  '242493',
#  '242674',
#  '266408',
#  '280197',
#  '285849',
#  '303475',
#  '303841',
#  '310334',
#  '312129',
#  '312131',
#  '324117',
#  '324647',
#  '324754',
#  '327075',
#  '335315',
#  '338016',
#  '349671',
#  '485427',
#  '512326',
#  '512560',
#  '513435',
#  '519045',
#  '519983',
#  '520695',
#  '521365',
#  '526378',
#  '526476',
#  '533599',
#  '534497',
#  '542433',
#  '542982',
#  '548680',
#  '549478',
#  '550421',
#  '550452',
#  '551550',
#  '551597',
#  '552274',
#  '553639',
#  '554001',
#  '558642',
#  '571457',
#  '580348',
#  '601066',
#  '602765',
#  '616881',
#  '620438',
#  '621069',
#  '630679',
#  '630783',
#  '634662',
#  '640115',
#  '640707',
#  '647975',
#  '660889',
#  '673151',
#  '683865',
#  '690574',
#  '704741',
#  '727946',
#  '731480',
#  '758837',
#  '790252',
#  '798720',
#  '819328',
#  '871165',
#  '916130',
#  '935807',
#  '940557',
#  '941024',
#  '972256',
#  '972647'}

# %%
book_set = pd.merge(df, bestsellers, on='isbn', how='left')
book_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11158 entries, 0 to 11157
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   isbn                11158 non-null  object
#  1   description_x       5698 non-null   object
#  2   categories          5597 non-null   object
#  3   title_x             11158 non-null  object
#  4   authors             11158 non-null  object
#  5   average_rating      11158 non-null  float64
#  6   num_pages           11158 non-null  int64
#  7   ratings_count       11158 non-null  int64
#  8   text_reviews_count  11158 non-null  int64
#  9   publication_date    11158 non-null  object
#  10  publisher           11158 non-null  object
#  11  rank                123 non-null    float64
#  12  price               123 non-null    float64
#  13  weeks_on_list       123 non-null    float64
#  14  title_y             123 non-null    object
#  15  description_y       114 non-null    object
#  16  published_date      123 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(3), object(9)
# memory usage: 1.4+ MB

# %%
book_set
# Out:
#          isbn     description_x
# 0      978596  Juvenile Fiction  \
# 1      935807  Juvenile Fiction
# 2      955489  Juvenile Fiction
# 3      965548  Juvenile Fiction
# 4      968258  Juvenile Fiction
# ...       ...               ...
# 11153  025441           Fiction
# 11154  011087           Fiction
# 11155  013196               NaN
# 11156  087882               NaN
# 11157  764698               NaN
#
#                                               categories
# 0      When Harry Potter and the Half-Blood Prince op...  \
# 1      In Harry Potter and the Order of the Phoenix, ...
# 2      When the Chamber of Secrets is opened again at...
# 3      For twelve long years, the dread fortress of A...
# 4      The first five years of Harry Potter magic are...
# ...                                                  ...
# 11153  No stranger to living and writing on the edge,...
# 11154  This comic and surreal novel about the beastli...
# 11155                                                NaN
# 11156                                                NaN
# 11157                                                NaN
#
#                                                  title_x
# 0      Harry Potter and the Half-Blood Prince (Harry ...  \
# 1      Harry Potter and the Order of the Phoenix (Har...
# 2      Harry Potter and the Chamber of Secrets (Harry...
# 3      Harry Potter and the Prisoner of Azkaban (Harr...
# 4      Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...                                                  ...
# 11153   Expelled from Eden: A William T. Vollmann Reader
# 11154                        You Bright and Risen Angels
# 11155                    The Ice-Shirt (Seven Dreams #1)
# 11156                                        Poor People
# 11157                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating
# 0                             J.K. Rowling/Mary GrandPré            4.57  \
# 1                             J.K. Rowling/Mary GrandPré            4.49
# 2                                           J.K. Rowling            4.42
# 3                             J.K. Rowling/Mary GrandPré            4.56
# 4                             J.K. Rowling/Mary GrandPré            4.78
# ...                                                  ...             ...
# 11153  William T. Vollmann/Larry McCaffery/Michael He...            4.06
# 11154                                William T. Vollmann            4.08
# 11155                                William T. Vollmann            3.96
# 11156                                William T. Vollmann            3.72
# 11157                                         Mark Twain            3.91
#
#        num_pages  ratings_count  text_reviews_count publication_date
# 0            652        2095690               27591        9/16/2006  \
# 1            870        2153167               29221         9/1/2004
# 2            352           6333                 244        11/1/2003
# 3            435        2339585               36325         5/1/2004
# 4           2690          41428                 164        9/13/2004
# ...          ...            ...                 ...              ...
# 11153        512            156                  20       12/21/2004
# 11154        635            783                  56        12/1/1988
# 11155        415            820                  95         8/1/1993
# 11156        434            769                 139        2/27/2007
# 11157        272            113                  12        5/28/2006
#
#              publisher  rank  price  weeks_on_list       title_y
# 0      Scholastic Inc.   NaN    NaN            NaN           NaN  \
# 1      Scholastic Inc.   3.0    0.0          330.0  HARRY POTTER
# 2           Scholastic   NaN    NaN            NaN           NaN
# 3      Scholastic Inc.   NaN    NaN            NaN           NaN
# 4           Scholastic   NaN    NaN            NaN           NaN
# ...                ...   ...    ...            ...           ...
# 11153    Da Capo Press   NaN    NaN            NaN           NaN
# 11154    Penguin Books   NaN    NaN            NaN           NaN
# 11155    Penguin Books   NaN    NaN            NaN           NaN
# 11156             Ecco   NaN    NaN            NaN           NaN
# 11157    Edimat Libros   NaN    NaN            NaN           NaN
#
#                                            description_y published_date
# 0                                                    NaN            NaT
# 1      A wizard hones his conjuring skills in the ser...     2015-08-02
# 2                                                    NaN            NaT
# 3                                                    NaN            NaT
# 4                                                    NaN            NaT
# ...                                                  ...            ...
# 11153                                                NaN            NaT
# 11154                                                NaN            NaT
# 11155                                                NaN            NaT
# 11156                                                NaN            NaT
# 11157                                                NaN            NaT
#
# [11158 rows x 17 columns]

# %%
book_set[~book_set.weeks_on_list.isnull()]
# Out:
#          isbn         description_x
# 1      935807      Juvenile Fiction  \
# 284    112241               Fiction
# 286    116925                   NaN
# 318    542433  Business & Economics
# 444    630783                   NaN
# ...       ...                   ...
# 10734  512560               Fiction
# 10762  819328                   NaN
# 10861  310334      Juvenile Fiction
# 10942  033051              Religion
# 10947  179280  Business & Economics
#
#                                               categories
# 1      In Harry Potter and the Order of the Phoenix, ...  \
# 284    "My heart is afraid that it will have to suffe...
# 286                                                  NaN
# 318    An updated edition of the best-selling guide f...
# 444                                                  NaN
# ...                                                  ...
# 10734  Ninety-something-year-old Jacob Jankowski reme...
# 10762                                                NaN
# 10861  When Camp Half-Blood, the only safe haven for ...
# 10942  Five volumes on sanctification published under...
# 10947  The author invites business readers to center ...
#
#                                                  title_x
# 1      Harry Potter and the Order of the Phoenix (Har...  \
# 284                                        The Alchemist
# 286    Fullmetal Alchemist  Vol. 3 (Fullmetal Alchemi...
# 318    Think and Grow Rich: The Landmark Bestseller N...
# 444    Euripides IV: Rhesus / The Suppliant Women / O...
# ...                                                  ...
# 10734                                Water for Elephants
# 10762                              La regina dei dannati
# 10861  The Sea of Monsters (Percy Jackson and the Oly...
# 10942                         The Complete Green Letters
# 10947                      Principle-Centered Leadership
#
#                                                  authors  average_rating
# 1                             J.K. Rowling/Mary GrandPré            4.49  \
# 284             Paulo Coelho/Alan R. Clarke/Özdemir İnce            3.86
# 286                        Hiromu Arakawa/Akira Watanabe            4.56
# 318                                        Napoleon Hill            4.18
# 444    Euripides/David Grene/Richmond Lattimore/Willi...            4.21
# ...                                                  ...             ...
# 10734                                         Sara Gruen            4.09
# 10762                         Anne Rice/Roberta Rambelli            3.89
# 10861                                       Rick Riordan            4.24
# 10942                                  Miles J. Stanford            4.20
# 10947                                   Stephen R. Covey            4.10
#
#        num_pages  ratings_count  text_reviews_count publication_date
# 1            870        2153167               29221         9/1/2004  \
# 284          197        1631221               55843         5/1/1993
# 286          192          16666                 299        9/13/2005
# 318          320          88897                2334         9/1/2005
# 444          307            560                   8       11/15/1968
# ...          ...            ...                 ...              ...
# 10734        335        1260027               52759         5/1/2007
# 10762        507            333                  18         2/1/1997
# 10861        280          10551                1205         4/1/2007
# 10942        336            293                  32         1/1/1984
# 10947        336          15003                 140        10/1/1992
#
#                          publisher  rank  price  weeks_on_list
# 1                  Scholastic Inc.   3.0   0.00          330.0  \
# 284                  HarperCollins   4.0   0.00          344.0
# 286                  VIZ Media LLC   4.0   0.00            0.0
# 318                 Tarcherperigee   3.0  50.00           25.0
# 444    University of Chicago Press   5.0  13.99            3.0
# ...                            ...   ...    ...            ...
# 10734              Algonquin Books   5.0  13.95          132.0
# 10762                          TEA   3.0   0.00            1.0
# 10861        Disney Hyperion Books   4.0   0.00          176.0
# 10942                    Zondervan   2.0   0.00            1.0
# 10947                   Free Press   4.0   0.00            2.0
#
#                                      title_y
# 1                               HARRY POTTER  \
# 284                            THE ALCHEMIST
# 286                     STEAL LIKE AN ARTIST
# 318                         BUILDING STORIES
# 444    NATIONAL GEOGRAPHIC KIDS ALMANAC 2012
# ...                                      ...
# 10734                    WATER FOR ELEPHANTS
# 10762                              BLOOD VOW
# 10861          PERCY JACKSON & THE OLYMPIANS
# 10942                                  TALON
# 10947                           FREAKONOMICS
#
#                                            description_y published_date
# 1      A wizard hones his conjuring skills in the ser...     2015-08-02
# 284    In this fable, a Spanish shepherd boy ventures...     2015-03-08
# 286    Presenting 10 principles to help readers disco...     2015-04-26
# 318    This is not your typical graphic novel: this b...     2013-05-05
# 444                                   Fascinating facts.     2011-07-03
# ...                                                  ...            ...
# 10734  Distraught after the death of his parents in a...     2011-08-21
# 10762  A recruit to the Black Dagger Brotherhood is e...     2016-12-25
# 10861      Children of the gods battle monsters of myth.     2010-12-05
# 10942                                                NaN     2016-03-27
# 10947  How to apply economic theory to almost everyth...     2014-05-04
#
# [123 rows x 17 columns]
