# %%
import pandas as pd

# %%
df1 = pd.read_csv('dylancastillo/books.csv')
df1['isbn'] = df1['isbn10']
df1.head(3)
# Out:
#           isbn13      isbn10         title subtitle  \
# 0  9780002005883  0002005883        Gilead      NaN
# 1  9780002261982  0002261987  Spider's Web  A Novel
# 2  9780006163831  0006163831  The One Tree      NaN
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# 1  Charles Osborne;Agatha Christie  Detective and mystery stories
# 2             Stephen R. Donaldson               American fiction
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# 2  http://books.google.com/books/content?id=OmQaw...
#
#                                          description  published_year  \
# 0  A NOVEL THAT READERS and critics have been eag...          2004.0
# 1  A new 'Christie for Christmas' -- a full-lengt...          2000.0
# ...

# %%
df2 = pd.read_csv('GoodReads/books.csv', index_col=0)
df2.head(3)
# Out:
#                                                     title  \
# bookID
# 1       Harry Potter and the Half-Blood Prince (Harry ...
# 2       Harry Potter and the Order of the Phoenix (Har...
# 4       Harry Potter and the Chamber of Secrets (Harry...
#
#                            authors  average_rating        isbn         isbn13  \
# bookID
# 1       J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 2       J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 4                     J.K. Rowling            4.42  0439554896  9780439554893
#
#        language_code  num_pages  ratings_count  text_reviews_count  \
# bookID
# 1                eng        652        2095690               27591
# 2                eng        870        2153167               29221
# 4                eng        352           6333                 244
#
#        publication_date        publisher
# bookID
# 1             9/16/2006  Scholastic Inc.
# ...

# %%
pd.merge(df1, df2, on='isbn', how='inner').dropna(how = 'any')
# Out:
#            isbn13_x      isbn10  \
# 4     9780006380832  0006380832
# 18    9780006754893  0006754899
# 20    9780007105045  0007105045
# 22    9780007116263  0007116268
# 30    9780007149827  0007149824
# ...             ...         ...
# 5671  9782940373154  2940373159
# 5674  9783791329284  3791329286
# 5675  9783856305581  3856305580
# 5680  9784770028037  4770028032
# 5685  9789042003408  9042003405
#
#                                             title_x  \
# 4                            Empires of the Monsoon
# 18                         A Small Pinch of Weather
# 20                                    Tree and Leaf
# 22    The Lord of the Rings, the Return of the King
# 30                    The Yiddish Policemen's Union
# ...                                             ...
# 5671                         Basics Illustration 01
# 5674                                 Joseph Cornell
# 5675                    C.G. Jung and Hermann Hesse
# ...
