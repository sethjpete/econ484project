# %%
"""
Goal:
Compute subsets of 4x200 samples from the NYT Best Seller Data. Use all data columns for matching.

Generate a list of the top 8000 books in total sales from the SPL data sets

Export to csv to be pasted into Google Sheets
""";

# %%
# Import bestseller data
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep
pd.set_option('display.max_columns', None)

# Import data
ndf = pd.read_csv('NYTBest/bestsellers.csv')
ndf = ndf[['isbn10', 'title', 'author', 'description', 'published_date', 'list_name', 'weeks_on_list', 'amazon_product_url']]
ndf.head(5)
# Out:
#        isbn10                    title  \
# 0  0316036242         WITCH AND WIZARD
# 1  0439023483         THE HUNGER GAMES
# 2  0439023491            CATCHING FIRE
# 3  0763644102  THE MAGICIAN’S ELEPHANT
# 4  0385738935                   FALLEN
#
#                                      author  \
# 0  James Patterson and Gabrielle Charbonnet
# 1                           Suzanne Collins
# 2                           Suzanne Collins
# 3                            Kate DiCamillo
# 4                               Lauren Kate
#
#                                          description published_date  \
# 0  One of each, brother and sister, flex their ne...     2010-01-03
# 1  In a dystopian future, a girl fights for survi...     2010-01-03
# 2     The protagonist of "The Hunger Games" returns.     2010-01-03
# 3  An orphan in search of his sister follows a fo...     2010-01-03
# 4  Thwarted love among misfits at a Savannah, Ga....     2010-01-03
#
#        list_name  weeks_on_list  \
# 0  Chapter Books              1
# 1  Chapter Books             67
# 2  Chapter Books             16
# 3  Chapter Books             15
# 4  Chapter Books              2
#
#                                   amazon_product_url
# 0  https://www.amazon.com/Witch-Wizard-James-Patt...
# 1  https://www.amazon.com/The-Hunger-Games-Suzann...
# 2  https://www.amazon.com/Catching-Fire-Hunger-Ga...
# 3  https://www.amazon.com/The-Magicians-Elephant-...
# 4  https://www.amazon.com/Fallen-Lauren-Kate/dp/0...

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61430 entries, 0 to 61429
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   isbn10              60146 non-null  object
#  1   title               61430 non-null  object
#  2   author              61361 non-null  object
#  3   description         53311 non-null  object
#  4   published_date      61430 non-null  object
#  5   list_name           61430 non-null  object
#  6   weeks_on_list       61430 non-null  int64
#  7   amazon_product_url  61430 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 3.7+ MB

# %%
# Drop certain null observations
ndf = ndf.dropna(subset=['author', 'isbn10'], how = 'any')
ndf = ndf.fillna('No Description')

# Also, sort by weeks on list and drop duplicate titles
ndf = ndf.sort_values(by=['weeks_on_list'], ascending=False)
ndf = ndf.drop_duplicates(subset=['title', 'author', 'isbn10'], keep='first')
ndf = ndf.reset_index(drop=True)
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8685 entries, 0 to 8684
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   isbn10              8685 non-null   object
#  1   title               8685 non-null   object
#  2   author              8685 non-null   object
#  3   description         8685 non-null   object
#  4   published_date      8685 non-null   object
#  5   list_name           8685 non-null   object
#  6   weeks_on_list       8685 non-null   int64
#  7   amazon_product_url  8685 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 542.9+ KB

# %%
# We're all good! All the data is cleaned up and ready to go. Let's get to work!
ndf.head(10)
# Out:
#        isbn10                                 title  \
# 0  0761148574  WHAT TO EXPECT WHEN YOU'RE EXPECTING
# 1  1419739034                  DIARY OF A WIMPY KID
# 2  0545791421                          HARRY POTTER
# 3  059035342X                          HARRY POTTER
# 4  1419727435                  DIARY OF A WIMPY KID
# 5  133829914X                          HARRY POTTER
# 6  0786838655         PERCY JACKSON & THE OLYMPIANS
# 7  1338263897                          HARRY POTTER
# 8  0545790352                          HARRY POTTER
# 9  1419725459                  DIARY OF A WIMPY KID
#
#                            author  \
# 0  Heidi Murkoff and Sharon Mazel
# 1                     Jeff Kinney
# 2                      JK Rowling
# 3                      JK Rowling
# 4                     Jeff Kinney
# 5                      JK Rowling
# 6                    Rick Riordan
# 7                      JK Rowling
# 8                      JK Rowling
# 9                     Jeff Kinney
#
#                                          description published_date  \
# 0                          Advice for parents-to-be.     2013-04-21
# 1        The travails and challenges of adolescence.     2019-12-29
# 2  A wizard hones his conjuring skills in the ser...     2019-12-29
# 3  A wizard hones his conjuring skills in the ser...     2019-10-13
# 4        The travails and challenges of adolescence.     2019-09-22
# 5  A wizard hones his conjuring skills in the ser...     2019-05-26
# 6               A boy battles mythological monsters.     2019-09-15
# 7  A wizard hones his conjuring skills in the ser...     2019-01-20
# 8  A wizard hones his conjuring skills in the ser...     2018-11-25
# 9        The travails and challenges of adolescence.     2018-11-11
#
#           list_name  weeks_on_list  \
# 0  Paperback Advice            607
# 1      Series Books            561
# 2      Series Books            560
# 3      Series Books            549
# 4      Series Books            547
# 5      Series Books            529
# 6      Series Books            517
# 7      Series Books            511
# 8      Series Books            503
# 9      Series Books            502
#
#                                   amazon_product_url
# 0  https://www.amazon.com/What-Expect-Youre-Expec...
# 1  https://www.amazon.com/Diary-Wimpy-Kid-Hard-Lu...
# 2  https://www.amazon.com/Harry-Potter-And-Order-...
# 3  https://www.amazon.com/Harry-Potter-And-Order-...
# 4  https://www.amazon.com/Diary-Wimpy-Kid-Hard-Lu...
# 5  https://www.amazon.com/Harry-Potter-And-Order-...
# 6  https://www.amazon.com/Titans-Curse-Percy-Jack...
# 7  https://www.amazon.com/Harry-Potter-And-Order-...
# 8  https://www.amazon.com/Harry-Potter-And-Order-...
# 9  https://www.amazon.com/Diary-Wimpy-Kid-Hard-Lu...

# %%
"""An interesting thing is happening here... 
The title is way too general, and the amazon product url does not map to the correct link for the relevant isbn.
We have to fix this!
Method: Manual web-scraping :(
""";

# %%
# Time to iterate over the entire dataframe...
# Requests didn't work, so we need to set up selenium.
# https://www.geeksforgeeks.org/how-to-install-selenium-on-macos/#
# This takes like 40 seconds to open :/
driver = webdriver.Chrome(executable_path = 'selenium-3.141.0/selenium/webdriver/chrome/webdriver.py')
   
#URL of the website 
url = "https://www.geeksforgeeks.org/"
df = pd.DataFrame(columns = ['isbn10', 'isbn13', 'title','authors', 'edition', 'binding', 'publisher', 'publish_year'])
for i in range(len(ndf)):
    isbn = ndf.loc[i, 'isbn10']
    url = 'https://isbnsearch.org/isbn/' + str(isbn)
    driver.get(url)
    try:
        info = driver.find_element(By.CLASS_NAME, 'bookinfo').text
    except:
        inp = input('Continue?')
        if inp == 'y':
            info = driver.find_element(By.CLASS_NAME, 'bookinfo').text
        if inp == 'n':
            next
    for idx, line in enumerate(info.splitlines()):
        if idx == 0:
            df.loc[i, 'title'] = line
        if idx == 1:
            df.loc[i, 'isbn13'] = ' '.join(line.split(' ')[1:]).strip()
        if idx == 2:
            df.loc[i, 'isbn10'] = ' '.join(line.split(' ')[1:]).strip()
        if idx == 3:
            df.loc[i, 'authors'] = ' '.join(line.split(' ')[1:]).strip()
        if idx == 4:
            df.loc[i, 'edition'] = ' '.join(line.split(' ')[1:]).strip()
        if idx == 5:
            df.loc[i, 'binding'] = ' '.join(line.split(' ')[1:]).strip()
        if idx == 6:
            df.loc[i, 'publisher'] = ' '.join(line.split(' ')[1:]).strip()
        if idx == 7:
            df.loc[i, 'publish_year'] = ' '.join(line.split(' ')[1:]).strip()
    print(f"Completion: {i / len(ndf) : .2%}", end="\r")
    sleep(.3)
driver.close()
# Out:
# /var/folders/73/s_z37x2x4gv93j_kb8744gmh0000gn/T/ipykernel_17872/176828167.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path = 'selenium-3.141.0/selenium/webdriver/chrome/webdriver.py')
# https://isbnsearch.org/isbn/0761148574
# https://isbnsearch.org/isbn/1419739034
# https://isbnsearch.org/isbn/0545791421
# https://isbnsearch.org/isbn/059035342X
# https://isbnsearch.org/isbn/1419727435
# https://isbnsearch.org/isbn/133829914X
# https://isbnsearch.org/isbn/0786838655
# https://isbnsearch.org/isbn/1338263897
# https://isbnsearch.org/isbn/0545790352
# https://isbnsearch.org/isbn/1419725459
# https://isbnsearch.org/isbn/1338262181
# https://isbnsearch.org/isbn/1338218395
# https://isbnsearch.org/isbn/1484707230
# https://isbnsearch.org/isbn/0545791340
# https://isbnsearch.org/isbn/0545791324
# https://isbnsearch.org/isbn/1338267108
# https://isbnsearch.org/isbn/1419723448
# https://isbnsearch.org/isbn/133821666X
# https://isbnsearch.org/isbn/1338099132
# https://isbnsearch.org/isbn/0062315005
# https://isbnsearch.org/isbn/1338132318
# https://isbnsearch.org/isbn/1338109065
# https://isbnsearch.org/isbn/074324754X
# https://isbnsearch.org/isbn/1419717014
# https://isbnsearch.org/isbn/1423131983
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/1338097679
# https://isbnsearch.org/isbn/0545850568
# https://isbnsearch.org/isbn/1423131894
# https://isbnsearch.org/isbn/0375725601
# https://isbnsearch.org/isbn/0061122416
# https://isbnsearch.org/isbn/141971189X
# https://isbnsearch.org/isbn/0439358078
# https://isbnsearch.org/isbn/0545044251
# https://isbnsearch.org/isbn/1534427201
# https://isbnsearch.org/isbn/080241270X
# https://isbnsearch.org/isbn/0802473156
# https://isbnsearch.org/isbn/0803736800
# https://isbnsearch.org/isbn/1419711326
# https://isbnsearch.org/isbn/0399255370
# https://isbnsearch.org/isbn/0316017930
# https://isbnsearch.org/isbn/1534426388
# https://isbnsearch.org/isbn/0307980537
# https://isbnsearch.org/isbn/0375842209
# https://isbnsearch.org/isbn/0439064872
# https://isbnsearch.org/isbn/0375868267
# https://isbnsearch.org/isbn/0375868259
# https://isbnsearch.org/isbn/1534405607
# https://isbnsearch.org/isbn/0811879542
# https://isbnsearch.org/isbn/1419705849
# https://isbnsearch.org/isbn/0375868240
# https://isbnsearch.org/isbn/1423136802
# https://isbnsearch.org/isbn/0545132061
# https://isbnsearch.org/isbn/1401216676
# https://isbnsearch.org/isbn/0375868232
# https://isbnsearch.org/isbn/0811877825
# https://isbnsearch.org/isbn/0375869026
# https://isbnsearch.org/isbn/0316268399
# https://isbnsearch.org/isbn/0375856501
# https://isbnsearch.org/isbn/0545229936
# https://isbnsearch.org/isbn/0316032832
# https://isbnsearch.org/isbn/0679603751
# https://isbnsearch.org/isbn/0545317800
# https://isbnsearch.org/isbn/0316007722
# https://isbnsearch.org/isbn/0385376715
# https://isbnsearch.org/isbn/0143038419
# https://isbnsearch.org/isbn/0316067938
# https://isbnsearch.org/isbn/1400052181
# https://isbnsearch.org/isbn/1481479202
# https://isbnsearch.org/isbn/0849946158
# https://isbnsearch.org/isbn/0143038257
# https://isbnsearch.org/isbn/1423101472
# https://isbnsearch.org/isbn/1338347217
# https://isbnsearch.org/isbn/0810993139
# https://isbnsearch.org/isbn/1423101499
# https://isbnsearch.org/isbn/1338271512
# https://isbnsearch.org/isbn/1419702238
# https://isbnsearch.org/isbn/031617615X
# https://isbnsearch.org/isbn/0374533555
# https://isbnsearch.org/isbn/1423101502
# https://isbnsearch.org/isbn/0553573403
# https://isbnsearch.org/isbn/0762447699
# https://isbnsearch.org/isbn/0545663261
# https://isbnsearch.org/isbn/1400064163
# https://isbnsearch.org/isbn/0812974492
# https://isbnsearch.org/isbn/1607060760
# https://isbnsearch.org/isbn/081298496X
# https://isbnsearch.org/isbn/0439023513
# https://isbnsearch.org/isbn/1338271504
# https://isbnsearch.org/isbn/0553513095
# https://isbnsearch.org/isbn/0545326990
# https://isbnsearch.org/isbn/141970642X
# https://isbnsearch.org/isbn/0590846280
# https://isbnsearch.org/isbn/1423103343
# https://isbnsearch.org/isbn/1423113497
# https://isbnsearch.org/isbn/1582701709
# https://isbnsearch.org/isbn/1481457047
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/1595586431
# https://isbnsearch.org/isbn/0385388896
# https://isbnsearch.org/isbn/1416995757
# https://isbnsearch.org/isbn/006236491X
# https://isbnsearch.org/isbn/1419708457
# https://isbnsearch.org/isbn/0545586178
# https://isbnsearch.org/isbn/0061537969
# https://isbnsearch.org/isbn/0439023521
# https://isbnsearch.org/isbn/0544336267
# https://isbnsearch.org/isbn/1607747316
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0385738781
# https://isbnsearch.org/isbn/1607747308
# https://isbnsearch.org/isbn/144947425X
# https://isbnsearch.org/isbn/031612558X
# https://isbnsearch.org/isbn/0062457713
# https://isbnsearch.org/isbn/0385737955
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/1442416912
# https://isbnsearch.org/isbn/1466858494
# https://isbnsearch.org/isbn/142314189X
# https://isbnsearch.org/isbn/0545499089
# https://isbnsearch.org/isbn/0316013692
# https://isbnsearch.org/isbn/0312594437
# https://isbnsearch.org/isbn/1524851841
# https://isbnsearch.org/isbn/1582406723
# https://isbnsearch.org/isbn/0964729237
# https://isbnsearch.org/isbn/0810984911
# https://isbnsearch.org/isbn/031608736X
# https://isbnsearch.org/isbn/0345803485
# https://isbnsearch.org/isbn/0385738765
# https://isbnsearch.org/isbn/0307352153
# https://isbnsearch.org/isbn/0062498533
# https://isbnsearch.org/isbn/0375893776
# https://isbnsearch.org/isbn/1449497748
# https://isbnsearch.org/isbn/1423101480
# https://isbnsearch.org/isbn/0316027650
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0307454541
# https://isbnsearch.org/isbn/0762424931
# https://isbnsearch.org/isbn/0064407667
# https://isbnsearch.org/isbn/0307957659
# https://isbnsearch.org/isbn/1423119509
# https://isbnsearch.org/isbn/1442416890
# https://isbnsearch.org/isbn/0142402516
# https://isbnsearch.org/isbn/0312370849
# https://isbnsearch.org/isbn/1250000246
# https://isbnsearch.org/isbn/0316010669
# https://isbnsearch.org/isbn/0062872346
# https://isbnsearch.org/isbn/142313494X
# https://isbnsearch.org/isbn/0143125478
# https://isbnsearch.org/isbn/1338271490
# https://isbnsearch.org/isbn/0312650256
# https://isbnsearch.org/isbn/1449489915
# https://isbnsearch.org/isbn/1565125606
# https://isbnsearch.org/isbn/1442487690
# https://isbnsearch.org/isbn/1449462308
# https://isbnsearch.org/isbn/1442416874
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/014242417X
# https://isbnsearch.org/isbn/014241493X
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/1439163847
# https://isbnsearch.org/isbn/1881273156
# https://isbnsearch.org/isbn/0307588386
# https://isbnsearch.org/isbn/0316160202
# https://isbnsearch.org/isbn/0590634275
# https://isbnsearch.org/isbn/1442416882
# https://isbnsearch.org/isbn/031632406X
# https://isbnsearch.org/isbn/0545265355
# https://isbnsearch.org/isbn/0930289234
# https://isbnsearch.org/isbn/0312650248
# https://isbnsearch.org/isbn/006245773X
# https://isbnsearch.org/isbn/1401323251
# https://isbnsearch.org/isbn/0803741715
# https://isbnsearch.org/isbn/1338323210
# https://isbnsearch.org/isbn/0061992275
# https://isbnsearch.org/isbn/0806532254
# https://isbnsearch.org/isbn/1338236598
# https://isbnsearch.org/isbn/0439023491
# https://isbnsearch.org/isbn/0143130838
# https://isbnsearch.org/isbn/1612620248
# https://isbnsearch.org/isbn/1423161610
# https://isbnsearch.org/isbn/0307476073
# https://isbnsearch.org/isbn/0545540607
# https://isbnsearch.org/isbn/0316067601
# https://isbnsearch.org/isbn/0316175862
# https://isbnsearch.org/isbn/1423128192
# https://isbnsearch.org/isbn/1442416920
# https://isbnsearch.org/isbn/1449462278
# https://isbnsearch.org/isbn/0544609719
# https://isbnsearch.org/isbn/081298160X
# https://isbnsearch.org/isbn/0718077296
# https://isbnsearch.org/isbn/0061555274
# https://isbnsearch.org/isbn/1338216236
# https://isbnsearch.org/isbn/037589988X
# https://isbnsearch.org/isbn/1423155149
# https://isbnsearch.org/isbn/0345803493
# https://isbnsearch.org/isbn/0062111116
# https://isbnsearch.org/isbn/1481421840
# https://isbnsearch.org/isbn/038549081X
# https://isbnsearch.org/isbn/1594746036
# https://isbnsearch.org/isbn/0061555223
# https://isbnsearch.org/isbn/0061906220
# https://isbnsearch.org/isbn/1582406197
# https://isbnsearch.org/isbn/0399155341
# https://isbnsearch.org/isbn/0439813786
# https://isbnsearch.org/isbn/0761187480
# https://isbnsearch.org/isbn/0761147632
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/1484709888
# https://isbnsearch.org/isbn/0439023483
# https://isbnsearch.org/isbn/1338236571
# https://isbnsearch.org/isbn/0307589382
# https://isbnsearch.org/isbn/0805448853
# https://isbnsearch.org/isbn/1582346186
# https://isbnsearch.org/isbn/0345803507
# https://isbnsearch.org/isbn/1423146735
# https://isbnsearch.org/isbn/0545298415
# https://isbnsearch.org/isbn/0062111086
# https://isbnsearch.org/isbn/1442487674
# https://isbnsearch.org/isbn/0307279464
# https://isbnsearch.org/isbn/0061555185
# https://isbnsearch.org/isbn/1101905492
# https://isbnsearch.org/isbn/1524714682
# https://isbnsearch.org/isbn/0735232148
# https://isbnsearch.org/isbn/1476746583
# https://isbnsearch.org/isbn/0307717836
# https://isbnsearch.org/isbn/006158326X
# https://isbnsearch.org/isbn/0062077015
# https://isbnsearch.org/isbn/0762448318
# https://isbnsearch.org/isbn/1594634025
# https://isbnsearch.org/isbn/0545298407
# https://isbnsearch.org/isbn/0399590501
# https://isbnsearch.org/isbn/0061555150
# https://isbnsearch.org/isbn/0374531269
# https://isbnsearch.org/isbn/0062209272
# https://isbnsearch.org/isbn/1608198065
# https://isbnsearch.org/isbn/0142414123
# https://isbnsearch.org/isbn/0312606168
# https://isbnsearch.org/isbn/0316017922
# https://isbnsearch.org/isbn/1250170974
# https://isbnsearch.org/isbn/0143034758
# https://isbnsearch.org/isbn/0375714367
# https://isbnsearch.org/isbn/0307341577
# https://isbnsearch.org/isbn/0307588378
# https://isbnsearch.org/isbn/1594746036
# https://isbnsearch.org/isbn/0062376330
# https://isbnsearch.org/isbn/1609580834
# https://isbnsearch.org/isbn/0061950726
# https://isbnsearch.org/isbn/0545298393
# https://isbnsearch.org/isbn/0062278789
# https://isbnsearch.org/isbn/1607065967
# https://isbnsearch.org/isbn/0062376578
# https://isbnsearch.org/isbn/1607749769
# https://isbnsearch.org/isbn/0451532457
# https://isbnsearch.org/isbn/0316206644
# https://isbnsearch.org/isbn/030745455X
# https://isbnsearch.org/isbn/0061996653
# https://isbnsearch.org/isbn/1594749310
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0143109464
# https://isbnsearch.org/isbn/0062872257
# https://isbnsearch.org/isbn/0553579908
# https://isbnsearch.org/isbn/0698185390
# https://isbnsearch.org/isbn/006202406X
# https://isbnsearch.org/isbn/1250043220
# https://isbnsearch.org/isbn/0062238868
# https://isbnsearch.org/isbn/1442449632
# https://isbnsearch.org/isbn/0810996162
# https://isbnsearch.org/isbn/0062316117
# https://isbnsearch.org/isbn/1451695195
# https://isbnsearch.org/isbn/0307949486
# https://isbnsearch.org/isbn/1449427774
# https://isbnsearch.org/isbn/1607066017
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0062089447
# https://isbnsearch.org/isbn/1416971718
# https://isbnsearch.org/isbn/1524741426
# https://isbnsearch.org/isbn/0448455579
# https://isbnsearch.org/isbn/0545290597
# https://isbnsearch.org/isbn/1594745137
# https://isbnsearch.org/isbn/1604332379
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/031612091X
# https://isbnsearch.org/isbn/0448478633
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0756655293
# https://isbnsearch.org/isbn/1421580365
# https://isbnsearch.org/isbn/0307473473
# https://isbnsearch.org/isbn/0312567480
# https://isbnsearch.org/isbn/0307887952
# https://isbnsearch.org/isbn/0545880831
# https://isbnsearch.org/isbn/0399163611
# https://isbnsearch.org/isbn/0316191868
# https://isbnsearch.org/isbn/037571457X
# https://isbnsearch.org/isbn/0812993543
# https://isbnsearch.org/isbn/0143124544
# https://isbnsearch.org/isbn/0061992259
# https://isbnsearch.org/isbn/1594633665
# https://isbnsearch.org/isbn/0545813875
# https://isbnsearch.org/isbn/030726999X
# https://isbnsearch.org/isbn/0307949508
# https://isbnsearch.org/isbn/0316101842
# https://isbnsearch.org/isbn/0448482991
# https://isbnsearch.org/isbn/0307465357
# https://isbnsearch.org/isbn/0762424168
# https://isbnsearch.org/isbn/1932664084
# https://isbnsearch.org/isbn/0061996637
# https://isbnsearch.org/isbn/0547577311
# https://isbnsearch.org/isbn/0062300555
# https://isbnsearch.org/isbn/1476738025
# https://isbnsearch.org/isbn/1400201659
# https://isbnsearch.org/isbn/0805093079
# https://isbnsearch.org/isbn/006211445X
# https://isbnsearch.org/isbn/1592408419
# https://isbnsearch.org/isbn/0307433846
# https://isbnsearch.org/isbn/140120841X
# https://isbnsearch.org/isbn/0448483203
# https://isbnsearch.org/isbn/0553418025
# https://isbnsearch.org/isbn/0307886271
# https://isbnsearch.org/isbn/006208237X
# https://isbnsearch.org/isbn/0525478817
# https://isbnsearch.org/isbn/0307476154
# https://isbnsearch.org/isbn/1442449616
# https://isbnsearch.org/isbn/0807047414
# https://isbnsearch.org/isbn/1501106481
# https://isbnsearch.org/isbn/1101934859
# https://isbnsearch.org/isbn/031603620X
# https://isbnsearch.org/isbn/0545285046
# https://isbnsearch.org/isbn/0545935172
# https://isbnsearch.org/isbn/0307931471
# https://isbnsearch.org/isbn/0399256180
# https://isbnsearch.org/isbn/1451648650
# https://isbnsearch.org/isbn/0312379838
# https://isbnsearch.org/isbn/1421585642
# https://isbnsearch.org/isbn/1429996870
# https://isbnsearch.org/isbn/0062316109
# https://isbnsearch.org/isbn/0812550706
# https://isbnsearch.org/isbn/0062797158
# https://isbnsearch.org/isbn/1455570249
# https://isbnsearch.org/isbn/0735219095
# https://isbnsearch.org/isbn/1603093001
# https://isbnsearch.org/isbn/1932664122
# https://isbnsearch.org/isbn/1400049628
# https://isbnsearch.org/isbn/0385523394
# https://isbnsearch.org/isbn/1338344056
# https://isbnsearch.org/isbn/0545060508
# https://isbnsearch.org/isbn/1442449624
# https://isbnsearch.org/isbn/159514188X
# https://isbnsearch.org/isbn/149262246X
# https://isbnsearch.org/isbn/0062392174
# https://isbnsearch.org/isbn/1451681755
# https://isbnsearch.org/isbn/0399250573
# https://isbnsearch.org/isbn/1434768511
# https://isbnsearch.org/isbn/1612130593
# https://isbnsearch.org/isbn/1250076226
# https://isbnsearch.org/isbn/0399255001
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0316044695
# https://isbnsearch.org/isbn/1466850604
# https://isbnsearch.org/isbn/030758836X
# https://isbnsearch.org/isbn/0062345214
# https://isbnsearch.org/isbn/1594744769
# https://isbnsearch.org/isbn/0062125915
# https://isbnsearch.org/isbn/0060731338
# https://isbnsearch.org/isbn/1449486797
# https://isbnsearch.org/isbn/0307279189
# https://isbnsearch.org/isbn/0393338827
# https://isbnsearch.org/isbn/0393609391
# https://isbnsearch.org/isbn/142311339X
# https://isbnsearch.org/isbn/0316322423
# https://isbnsearch.org/isbn/0062300547
# https://isbnsearch.org/isbn/039335315X
# https://isbnsearch.org/isbn/0735220697
# https://isbnsearch.org/isbn/0143127748
# https://isbnsearch.org/isbn/0375863591
# https://isbnsearch.org/isbn/1423113381
# https://isbnsearch.org/isbn/142319957X
# https://isbnsearch.org/isbn/1595141715
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0399588191
# https://isbnsearch.org/isbn/0316036196
# https://isbnsearch.org/isbn/0394747232
# https://isbnsearch.org/isbn/0679603859
# https://isbnsearch.org/isbn/0061996610
# https://isbnsearch.org/isbn/0553897845
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/1612130615
# https://isbnsearch.org/isbn/1439122431
# https://isbnsearch.org/isbn/1601422210
# https://isbnsearch.org/isbn/0804190119
# https://isbnsearch.org/isbn/1442416866
# https://isbnsearch.org/isbn/0061728977
# https://isbnsearch.org/isbn/0062392190
# https://isbnsearch.org/isbn/0553801473
# https://isbnsearch.org/isbn/0312577222
# https://isbnsearch.org/isbn/0062081861
# https://isbnsearch.org/isbn/0307887448
# https://isbnsearch.org/isbn/0525555366
# https://isbnsearch.org/isbn/0307381374
# https://isbnsearch.org/isbn/0805095152
# https://isbnsearch.org/isbn/0545060397
# https://isbnsearch.org/isbn/0345529375
# https://isbnsearch.org/isbn/0062059955
# https://isbnsearch.org/isbn/0307346617
# https://isbnsearch.org/isbn/0061720852
# https://isbnsearch.org/isbn/1623363586
# https://isbnsearch.org/isbn/0545504929
# https://isbnsearch.org/isbn/0316381993
# https://isbnsearch.org/isbn/0671027344
# https://isbnsearch.org/isbn/1423146727
# https://isbnsearch.org/isbn/1416589643
# https://isbnsearch.org/isbn/1484719328
# https://isbnsearch.org/isbn/1338214519
# https://isbnsearch.org/isbn/0448450526
# https://isbnsearch.org/isbn/0060899220
# https://isbnsearch.org/isbn/1609614798
# https://isbnsearch.org/isbn/039925207X
# https://isbnsearch.org/isbn/1442411929
# https://isbnsearch.org/isbn/1534451560
# https://isbnsearch.org/isbn/1932664491
# https://isbnsearch.org/isbn/1524763136
# https://isbnsearch.org/isbn/0307742482
# https://isbnsearch.org/isbn/081298840X
# https://isbnsearch.org/isbn/0743270754
# https://isbnsearch.org/isbn/1451696191
# https://isbnsearch.org/isbn/0545504902
# https://isbnsearch.org/isbn/0062351214
# https://isbnsearch.org/isbn/0448428563
# https://isbnsearch.org/isbn/0385530269
# https://isbnsearch.org/isbn/0062081012
# https://isbnsearch.org/isbn/0307341550
# https://isbnsearch.org/isbn/0425232204
# https://isbnsearch.org/isbn/1440697663
# https://isbnsearch.org/isbn/1416596364
# https://isbnsearch.org/isbn/0142410705
# https://isbnsearch.org/isbn/0385479565
# https://isbnsearch.org/isbn/0448484102
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0803730586
# https://isbnsearch.org/isbn/055357342X
# https://isbnsearch.org/isbn/0316056871
# https://isbnsearch.org/isbn/1452126992
# https://isbnsearch.org/isbn/0545935180
# https://isbnsearch.org/isbn/0393354253
# https://isbnsearch.org/isbn/0440237688
# https://isbnsearch.org/isbn/0316204269
# https://isbnsearch.org/isbn/0385349947
# https://isbnsearch.org/isbn/014241977X
# https://isbnsearch.org/isbn/039333306X
# https://isbnsearch.org/isbn/0439023491
# https://isbnsearch.org/isbn/0316098329
# https://isbnsearch.org/isbn/193266422X
# https://isbnsearch.org/isbn/1524769800
# https://isbnsearch.org/isbn/1616205679
# https://isbnsearch.org/isbn/1534437339
# https://isbnsearch.org/isbn/1416550607
# https://isbnsearch.org/isbn/0316055441
# https://isbnsearch.org/isbn/039959051X
# https://isbnsearch.org/isbn/031623480X
# https://isbnsearch.org/isbn/0810994739
# https://isbnsearch.org/isbn/0062300563
# https://isbnsearch.org/isbn/030740885X
# https://isbnsearch.org/isbn/1449420435
# https://isbnsearch.org/isbn/1338305816
# https://isbnsearch.org/isbn/0545581605
# https://isbnsearch.org/isbn/0670034827
# https://isbnsearch.org/isbn/0062377019
# https://isbnsearch.org/isbn/1338317385
# https://isbnsearch.org/isbn/148473274X
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/006211445X
# https://isbnsearch.org/isbn/1484746694
# https://isbnsearch.org/isbn/006172081X
# https://isbnsearch.org/isbn/0385340915
# https://isbnsearch.org/isbn/0062349872
# https://isbnsearch.org/isbn/0618871713
# https://isbnsearch.org/isbn/014241543X
# https://isbnsearch.org/isbn/1419712179
# https://isbnsearch.org/isbn/1423160916
# https://isbnsearch.org/isbn/1627792120
# https://isbnsearch.org/isbn/0545942209
# https://isbnsearch.org/isbn/1442403543
# https://isbnsearch.org/isbn/0345532015
# https://isbnsearch.org/isbn/1524741728
# https://isbnsearch.org/isbn/1101883081
# https://isbnsearch.org/isbn/1563893428
# https://isbnsearch.org/isbn/0545060486
# https://isbnsearch.org/isbn/1938298071
# https://isbnsearch.org/isbn/0553496646
# https://isbnsearch.org/isbn/0545175364
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0062310631
# https://isbnsearch.org/isbn/0316055433
# https://isbnsearch.org/isbn/0812988418
# https://isbnsearch.org/isbn/0763676713
# https://isbnsearch.org/isbn/0316080845
# https://isbnsearch.org/isbn/0316007544
# https://isbnsearch.org/isbn/0316272620
# https://isbnsearch.org/isbn/1609611543
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0316204366
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/1419721372
# https://isbnsearch.org/isbn/1401927181
# https://isbnsearch.org/isbn/0399181776
# https://isbnsearch.org/isbn/1451695209
# https://isbnsearch.org/isbn/1250012570
# https://isbnsearch.org/isbn/1501115073
# https://isbnsearch.org/isbn/0399172750
# https://isbnsearch.org/isbn/0545206952
# https://isbnsearch.org/isbn/0763655988
# https://isbnsearch.org/isbn/159285849X
# https://isbnsearch.org/isbn/1416980083
# https://isbnsearch.org/isbn/0544272994
# https://isbnsearch.org/isbn/0399256709
# https://isbnsearch.org/isbn/1451648553
# https://isbnsearch.org/isbn/0316355895
# https://isbnsearch.org/isbn/1501100106
# https://isbnsearch.org/isbn/0062363603
# https://isbnsearch.org/isbn/0553496700
# https://isbnsearch.org/isbn/1934964387
# https://isbnsearch.org/isbn/0142425834
# https://isbnsearch.org/isbn/1451688091
# https://isbnsearch.org/isbn/0375856110
# https://isbnsearch.org/isbn/0062110586
# https://isbnsearch.org/isbn/1451648537
# https://isbnsearch.org/isbn/0062024035
# https://isbnsearch.org/isbn/0440212561
# https://isbnsearch.org/isbn/0062002945
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0553582011
# https://isbnsearch.org/isbn/0763655996
# https://isbnsearch.org/isbn/076366040X
# https://isbnsearch.org/isbn/0812971833
# https://isbnsearch.org/isbn/1400076315
# https://isbnsearch.org/isbn/0425284700
# https://isbnsearch.org/isbn/0310330912
# https://isbnsearch.org/isbn/0545060478
# https://isbnsearch.org/isbn/1595143068
# https://isbnsearch.org/isbn/0736431187
# https://isbnsearch.org/isbn/0545919770
# https://isbnsearch.org/isbn/1632154560
# https://isbnsearch.org/isbn/0345803787
# https://isbnsearch.org/isbn/1501173219
# https://isbnsearch.org/isbn/0385742886
# https://isbnsearch.org/isbn/031631613X
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/014198600X
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0399588183
# https://isbnsearch.org/isbn/1421580373
# https://isbnsearch.org/isbn/1338214489
# https://isbnsearch.org/isbn/1401224687
# https://isbnsearch.org/isbn/1423140591
# https://isbnsearch.org/isbn/0545175348
# https://isbnsearch.org/isbn/141974027X
# https://isbnsearch.org/isbn/1452109206
# https://isbnsearch.org/isbn/0545912407
# https://isbnsearch.org/isbn/0698138635
# https://isbnsearch.org/isbn/039335668X
# https://isbnsearch.org/isbn/0399592520
# https://isbnsearch.org/isbn/0545935202
# https://isbnsearch.org/isbn/014311638X
# https://isbnsearch.org/isbn/0062304186
# https://isbnsearch.org/isbn/1439164967
# https://isbnsearch.org/isbn/1442468351
# https://isbnsearch.org/isbn/006114097X
# https://isbnsearch.org/isbn/1492670022
# https://isbnsearch.org/isbn/0142420891
# https://isbnsearch.org/isbn/030746363X
# https://isbnsearch.org/isbn/0385534248
# https://isbnsearch.org/isbn/0374386153
# https://isbnsearch.org/isbn/0763660531
# https://isbnsearch.org/isbn/1455556556
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/1596434023
# https://isbnsearch.org/isbn/1607066920
# https://isbnsearch.org/isbn/006088732X
# https://isbnsearch.org/isbn/0143110438
# https://isbnsearch.org/isbn/0393609405
# https://isbnsearch.org/isbn/1524731668
# https://isbnsearch.org/isbn/1455570230
# https://isbnsearch.org/isbn/1451621388
# https://isbnsearch.org/isbn/0399252053
# https://isbnsearch.org/isbn/152473165X
# https://isbnsearch.org/isbn/1501111116
# https://isbnsearch.org/isbn/0545175305
# https://isbnsearch.org/isbn/0553447459
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0307731715
# https://isbnsearch.org/isbn/0062310666
# https://isbnsearch.org/isbn/0385341008
# https://isbnsearch.org/isbn/0061944386
# https://isbnsearch.org/isbn/0761151125
# https://isbnsearch.org/isbn/0545060435
# https://isbnsearch.org/isbn/0765388111
# https://isbnsearch.org/isbn/1423113454
# https://isbnsearch.org/isbn/006231064X
# https://isbnsearch.org/isbn/0735224315
# https://isbnsearch.org/isbn/0735224293
# https://isbnsearch.org/isbn/0062387650
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/1501132954
# https://isbnsearch.org/isbn/030740577X
# https://isbnsearch.org/isbn/1612620256
# https://isbnsearch.org/isbn/0316201561
# https://isbnsearch.org/isbn/1476753830
# https://isbnsearch.org/isbn/0770435629
# https://isbnsearch.org/isbn/1627790624
# https://isbnsearch.org/isbn/1401235417
# https://isbnsearch.org/isbn/1476728747
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0062409859
# https://isbnsearch.org/isbn/0062387677
# https://isbnsearch.org/isbn/1565125851
# https://isbnsearch.org/isbn/1476755868
# https://isbnsearch.org/isbn/1442426748
# https://isbnsearch.org/isbn/0316013560
# https://isbnsearch.org/isbn/1609450787
# https://isbnsearch.org/isbn/0618982507
# https://isbnsearch.org/isbn/0062024043
# https://isbnsearch.org/isbn/0756686067
# https://isbnsearch.org/isbn/0307408876
# https://isbnsearch.org/isbn/1401226930
# https://isbnsearch.org/isbn/0805098542
# https://isbnsearch.org/isbn/1416983082
# https://isbnsearch.org/isbn/0385542690
# https://isbnsearch.org/isbn/1338214438
# https://isbnsearch.org/isbn/0385542364
# https://isbnsearch.org/isbn/1617750255
# https://isbnsearch.org/isbn/1934964107
# https://isbnsearch.org/isbn/0307593673
# https://isbnsearch.org/isbn/1484720970
# https://isbnsearch.org/isbn/1416583432
# https://isbnsearch.org/isbn/006282015X
# https://isbnsearch.org/isbn/1596435739
# https://isbnsearch.org/isbn/0307454568
# https://isbnsearch.org/isbn/0393338398
# https://isbnsearch.org/isbn/1101996986
# https://isbnsearch.org/isbn/0307946711
# https://isbnsearch.org/isbn/0785134352
# https://isbnsearch.org/isbn/0761159134
# https://isbnsearch.org/isbn/0544107713
# https://isbnsearch.org/isbn/0307387097
# https://isbnsearch.org/isbn/0307450732
# https://isbnsearch.org/isbn/0805096671
# https://isbnsearch.org/isbn/0062422502
# https://isbnsearch.org/isbn/080509668X
# https://isbnsearch.org/isbn/1481438255
# https://isbnsearch.org/isbn/0061781231
# https://isbnsearch.org/isbn/1401229891
# https://isbnsearch.org/isbn/0553496689
# https://isbnsearch.org/isbn/0062060015
# https://isbnsearch.org/isbn/1439168571
# https://isbnsearch.org/isbn/1582407754
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0399252517
# https://isbnsearch.org/isbn/0545919738
# https://isbnsearch.org/isbn/0545825016
# https://isbnsearch.org/isbn/1101939842
# https://isbnsearch.org/isbn/1416989560
# https://isbnsearch.org/isbn/0062194755
# https://isbnsearch.org/isbn/0307272117
# https://isbnsearch.org/isbn/0061910244
# https://isbnsearch.org/isbn/037583527X
# https://isbnsearch.org/isbn/0803740166
# https://isbnsearch.org/isbn/0446547573
# https://isbnsearch.org/isbn/0345803574
# https://isbnsearch.org/isbn/1400052173
# https://isbnsearch.org/isbn/1501112333
# https://isbnsearch.org/isbn/0310321913
# https://isbnsearch.org/isbn/0062082353
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/030796003X
# https://isbnsearch.org/isbn/039333838X
# https://isbnsearch.org/isbn/0375714839
# https://isbnsearch.org/isbn/1607068184
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0143126814
# https://isbnsearch.org/isbn/0062213423
# https://isbnsearch.org/isbn/0062194771
# https://isbnsearch.org/isbn/1616559454
# https://isbnsearch.org/isbn/1421585650
# https://isbnsearch.org/isbn/0553418351
# https://isbnsearch.org/isbn/0062190040
# https://isbnsearch.org/isbn/0307474712
# https://isbnsearch.org/isbn/0156027321
# https://isbnsearch.org/isbn/0805096663
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/044042321X
# https://isbnsearch.org/isbn/006242713X
# https://isbnsearch.org/isbn/0997895810
# https://isbnsearch.org/isbn/1982127791
# https://isbnsearch.org/isbn/1416543074
# https://isbnsearch.org/isbn/0525953728
# https://isbnsearch.org/isbn/1484712374
# https://isbnsearch.org/isbn/1455508977
# https://isbnsearch.org/isbn/0393061027
# https://isbnsearch.org/isbn/1400209609
# https://isbnsearch.org/isbn/0143130153
# https://isbnsearch.org/isbn/0446563048
# https://isbnsearch.org/isbn/1419719025
# https://isbnsearch.org/isbn/0553446754
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0735219117
# https://isbnsearch.org/isbn/1595142509
# https://isbnsearch.org/isbn/0307887960
# https://isbnsearch.org/isbn/1484711874
# https://isbnsearch.org/isbn/1501106422
# https://isbnsearch.org/isbn/1484746422
# https://isbnsearch.org/isbn/0316129178
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/1455588997
# https://isbnsearch.org/isbn/1250038820
# https://isbnsearch.org/isbn/0525563709
# https://isbnsearch.org/isbn/141970933X
# https://isbnsearch.org/isbn/1607063298
# https://isbnsearch.org/isbn/1501156896
# https://isbnsearch.org/isbn/0375424334
# https://isbnsearch.org/isbn/082340417X
# https://isbnsearch.org/isbn/0307977617
# https://isbnsearch.org/isbn/0547345666
# https://isbnsearch.org/isbn/1592407331
# https://isbnsearch.org/isbn/1455556564
# https://isbnsearch.org/isbn/1501135929
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0316349542
# https://isbnsearch.org/isbn/0545942152
# https://isbnsearch.org/isbn/0062363611
# https://isbnsearch.org/isbn/031612737X
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0545123267
# https://isbnsearch.org/isbn/0525620931
# https://isbnsearch.org/isbn/0446567329
# https://isbnsearch.org/isbn/0553524267
# https://isbnsearch.org/isbn/0547848412
# https://isbnsearch.org/isbn/0448489325
# https://isbnsearch.org/isbn/1501154656
# https://isbnsearch.org/isbn/0385739133
# https://isbnsearch.org/isbn/0446562432
# https://isbnsearch.org/isbn/1101972971
# https://isbnsearch.org/isbn/0425274861
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/148471511X
# https://isbnsearch.org/isbn/1400078458
# https://isbnsearch.org/isbn/1481409204
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0385504225
# https://isbnsearch.org/isbn/0399544275
# https://isbnsearch.org/isbn/0316475114
# https://isbnsearch.org/isbn/0062423029
# https://isbnsearch.org/isbn/141697587X
# https://isbnsearch.org/isbn/038534919X
# https://isbnsearch.org/isbn/0545403359
# https://isbnsearch.org/isbn/110191176X
# https://isbnsearch.org/isbn/0143127551
# https://isbnsearch.org/isbn/0060936223
# https://isbnsearch.org/isbn/140031870X
# https://isbnsearch.org/isbn/1455508969
# https://isbnsearch.org/isbn/0385537867
# https://isbnsearch.org/isbn/0763660655
# https://isbnsearch.org/isbn/0061767581
# https://isbnsearch.org/isbn/075669812X
# https://isbnsearch.org/isbn/0312642075
# https://isbnsearch.org/isbn/0062024043
# https://isbnsearch.org/isbn/014751908X
# https://isbnsearch.org/isbn/0446552445
# https://isbnsearch.org/isbn/1619636107
# https://isbnsearch.org/isbn/0446547603
# https://isbnsearch.org/isbn/1455520667
# https://isbnsearch.org/isbn/1596436069
# https://isbnsearch.org/isbn/1101967684
# https://isbnsearch.org/isbn/1501106473
# https://isbnsearch.org/isbn/0679766758
# https://isbnsearch.org/isbn/0393072231
# https://isbnsearch.org/isbn/0060530944
# https://isbnsearch.org/isbn/1401242340
# https://isbnsearch.org/isbn/039925238X
# https://isbnsearch.org/isbn/0718079183
# https://isbnsearch.org/isbn/1770462082
# https://isbnsearch.org/isbn/0448447231
# https://isbnsearch.org/isbn/1442411902
# https://isbnsearch.org/isbn/1423140605
# https://isbnsearch.org/isbn/0718081536
# https://isbnsearch.org/isbn/031632793X
# https://isbnsearch.org/isbn/1250091845
# https://isbnsearch.org/isbn/0307272303
# https://isbnsearch.org/isbn/1421534754
# https://isbnsearch.org/isbn/1338304518
# https://isbnsearch.org/isbn/0786868724
# https://isbnsearch.org/isbn/0375413405
# https://isbnsearch.org/isbn/006228214X
# https://isbnsearch.org/isbn/1939457319
# https://isbnsearch.org/isbn/1596916710
# https://isbnsearch.org/isbn/0062194747
# https://isbnsearch.org/isbn/0061728985
# https://isbnsearch.org/isbn/0316245283
# https://isbnsearch.org/isbn/0307908275
# https://isbnsearch.org/isbn/152479628X
# https://isbnsearch.org/isbn/0062678426
# https://isbnsearch.org/isbn/0316168815
# https://isbnsearch.org/isbn/1770462090
# https://isbnsearch.org/isbn/1368003559
# https://isbnsearch.org/isbn/0375864350
# https://isbnsearch.org/isbn/1101997699
# https://isbnsearch.org/isbn/0062662805
# https://isbnsearch.org/isbn/0061962791
# https://isbnsearch.org/isbn/0061992704
# https://isbnsearch.org/isbn/145217380X
# https://isbnsearch.org/isbn/0756686970
# https://isbnsearch.org/isbn/0061928178
# https://isbnsearch.org/isbn/0316383295
# https://isbnsearch.org/isbn/0385343841
# https://isbnsearch.org/isbn/0142414727
# https://isbnsearch.org/isbn/0316346799
# https://isbnsearch.org/isbn/1582406987
# https://isbnsearch.org/isbn/1439170916
# https://isbnsearch.org/isbn/1416980067
# https://isbnsearch.org/isbn/0061969559
# https://isbnsearch.org/isbn/1607063271
# https://isbnsearch.org/isbn/1501124021
# https://isbnsearch.org/isbn/1368020038
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0062414151
# https://isbnsearch.org/isbn/0385386230
# https://isbnsearch.org/isbn/1401229689
# https://isbnsearch.org/isbn/0062087142
# https://isbnsearch.org/isbn/1492674311
# https://isbnsearch.org/isbn/1419715364
# https://isbnsearch.org/isbn/1609580427
# https://isbnsearch.org/isbn/1101946342
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/1476726094
# https://isbnsearch.org/isbn/0763692158
# https://isbnsearch.org/isbn/0062007289
# https://isbnsearch.org/isbn/1423121295
# https://isbnsearch.org/isbn/0399162593
# https://isbnsearch.org/isbn/1524797154
# https://isbnsearch.org/isbn/110190500X
# https://isbnsearch.org/isbn/1250007208
# https://isbnsearch.org/isbn/1455523550
# https://isbnsearch.org/isbn/1368020054
# https://isbnsearch.org/isbn/0545385776
# https://isbnsearch.org/isbn/0385386176
# https://isbnsearch.org/isbn/0545685478
# https://isbnsearch.org/isbn/0062268341
# https://isbnsearch.org/isbn/0385349181
# https://isbnsearch.org/isbn/160529442X
# https://isbnsearch.org/isbn/0316015474
# https://isbnsearch.org/isbn/1607069318
# https://isbnsearch.org/isbn/0062422995
# https://isbnsearch.org/isbn/0312590989
# https://isbnsearch.org/isbn/1451681763
# https://isbnsearch.org/isbn/1419710524
# https://isbnsearch.org/isbn/0985462736
# https://isbnsearch.org/isbn/0525426396
# https://isbnsearch.org/isbn/0307592731
# https://isbnsearch.org/isbn/1501142976
# https://isbnsearch.org/isbn/0062110624
# https://isbnsearch.org/isbn/1421576074
# https://isbnsearch.org/isbn/0061724882
# https://isbnsearch.org/isbn/0316327913
# https://isbnsearch.org/isbn/0399185046
# https://isbnsearch.org/isbn/1455584738
# https://isbnsearch.org/isbn/1423190874
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0761158464
# https://isbnsearch.org/isbn/0142422835
# https://isbnsearch.org/isbn/0785129219
# https://isbnsearch.org/isbn/1423140567
# https://isbnsearch.org/isbn/0316101699
# https://isbnsearch.org/isbn/1423188101
# https://isbnsearch.org/isbn/1534438378
# https://isbnsearch.org/isbn/0316044407
# https://isbnsearch.org/isbn/1607061813
# https://isbnsearch.org/isbn/006226835X
# https://isbnsearch.org/isbn/0316487481
# https://isbnsearch.org/isbn/1501175467
# https://isbnsearch.org/isbn/0345543254
# https://isbnsearch.org/isbn/1943200009
# https://isbnsearch.org/isbn/1421540320
# https://isbnsearch.org/isbn/1416980458
# https://isbnsearch.org/isbn/0345505387
# https://isbnsearch.org/isbn/1476772290
# https://isbnsearch.org/isbn/0446567337
# https://isbnsearch.org/isbn/0545658527
# https://isbnsearch.org/isbn/0316263893
# https://isbnsearch.org/isbn/1449410243
# https://isbnsearch.org/isbn/0385528752
# https://isbnsearch.org/isbn/1619634473
# https://isbnsearch.org/isbn/1607749734
# https://isbnsearch.org/isbn/1572245379
# https://isbnsearch.org/isbn/0446547565
# https://isbnsearch.org/isbn/1442495006
# https://isbnsearch.org/isbn/1416989420
# https://isbnsearch.org/isbn/1619634465
# https://isbnsearch.org/isbn/1416994157
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0062796984
# https://isbnsearch.org/isbn/0385537921
# https://isbnsearch.org/isbn/0307408868
# https://isbnsearch.org/isbn/1476755884
# https://isbnsearch.org/isbn/0316056863
# https://isbnsearch.org/isbn/1423183649
# https://isbnsearch.org/isbn/0545540623
# https://isbnsearch.org/isbn/0316193062
# https://isbnsearch.org/isbn/0345530578
# https://isbnsearch.org/isbn/1401223036
# https://isbnsearch.org/isbn/0735212163
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/1939457033
# https://isbnsearch.org/isbn/0061997188
# https://isbnsearch.org/isbn/0759529434
# https://isbnsearch.org/isbn/1442422335
# https://isbnsearch.org/isbn/0892969911
# https://isbnsearch.org/isbn/1596987855
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/1401242359
# https://isbnsearch.org/isbn/1423178289
# https://isbnsearch.org/isbn/1423134494
# https://isbnsearch.org/isbn/0385738935
# https://isbnsearch.org/isbn/0312590970
# https://isbnsearch.org/isbn/0307408841
# https://isbnsearch.org/isbn/1476726116
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0553380168
# https://isbnsearch.org/isbn/0316001929
# https://isbnsearch.org/isbn/1524732680
# https://isbnsearch.org/isbn/006204964X
# https://isbnsearch.org/isbn/1607064405
# https://isbnsearch.org/isbn/0385537859
# https://isbnsearch.org/isbn/0399252487
# https://isbnsearch.org/isbn/0803734190
# https://isbnsearch.org/isbn/0425263908
# https://isbnsearch.org/isbn/1401229662
# https://isbnsearch.org/isbn/1501168681
# https://isbnsearch.org/isbn/1603094008
# https://isbnsearch.org/isbn/1401248969
# https://isbnsearch.org/isbn/1476789886
# https://isbnsearch.org/isbn/None
# https://isbnsearch.org/isbn/0763678880
# https://isbnsearch.org/isbn/1492646318
# https://isbnsearch.org/isbn/0062101986
# https://isbnsearch.org/isbn/1338189611
# https://isbnsearch.org/isbn/078512179X
# https://isbnsearch.org/isbn/1595828117
# https://isbnsearch.org/isbn/1421533049
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 18
#      16     info = driver.find_element(By.CLASS_NAME, 'bookinfo').text
#      17 except:
# ---> 18     inp = input('Continue?')
#      19     if inp == 'y':
#      20         info = driver.find_element(By.CLASS_NAME, 'bookinfo').text
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
#    1173         "raw_input was called, but this frontend does not support input requests."
#    1174     )
# -> 1175 return self._input_request(
#    1176     str(prompt),
#    1177     self._parent_ident["shell"],
#    1178     self.get_parent("shell"),
#    1179     password=False,
#    1180 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py:1217, in Kernel._input_request(self, prompt, ident, parent, password)
#    1214             break
#    1215 except KeyboardInterrupt:
#    1216     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1217     raise KeyboardInterrupt("Interrupted by user") from None
#    1218 except Exception:
#    1219     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# Don't want to lose all of the hard work!
df.to_csv('Exported/NYTSelection.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 949 entries, 0 to 948
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   isbn10        949 non-null    object
#  1   isbn13        949 non-null    object
#  2   title         949 non-null    object
#  3   authors       949 non-null    object
#  4   edition       949 non-null    object
#  5   binding       949 non-null    object
#  6   publisher     945 non-null    object
#  7   publish_year  915 non-null    object
# dtypes: object(8)
# memory usage: 99.0+ KB

# %%
df['binding'].value_counts().to_csv('Exported/binding.csv')

# %%
allowed_bindings = ['Hardcover', 'Paperback', 'Kindle Edition', 'Mass Market Paperback']

# %%
# Must 
def adjust_rows2(row):
    if str(row['publish_year']) == 'nan' or str(row['publish_year'])[:5] == 'Price':
        row['publish_year'] = row['publisher']
        row['publisher'] = row['binding']
        row['binding'] = row['edition']
        row['edition'] = None
    # a second time!
    if str(row['publish_year']) == 'nan' or str(row['publish_year'])[:5] == 'Price':
        row['publish_year'] = row['publisher']
        row['publisher'] = row['binding']
        row['binding'] = None
        row['edition'] = None
    # some value-specific fixes
    if str(row['isbn10']) == '006202406X':
        row['authors'] = 'Veronica Roth'
        row['edition'] = '1st'
        row['binding'] = 'Hardcover'
        row['title'] = 'Allegiant'
    return row
df1 = df.apply(adjust_rows2, axis=1)

# %%
df1.to_csv('Exported/cleaned_NYT_Sel.csv')

# %%
print(df1.edition.value_counts())
print(df1.publish_year.value_counts())
# Out:
# Hardcover                416
# Paperback                382
# Kindle Edition           108
# Mass Market Paperback     29
# Board book                 4
# Product Bundle             1
# ePub                       1
# Library Binding            1
# Unknown Binding            1
# Spiral-bound               1
# 1                          1
# Comic                      1
# Name: binding, dtype: int64
# 2011        98
# 2015        92
# 2010        92
# 2012        90
# 2016        79
# 2013        71
# 2009        64
# 2014        59
# 2017        54
# 2019        52
# 2018        50
# 2007        28
# 2020        28
# 2008        23
# 2022        13
# 2006         9
# 2004         6
# 2005         5
# 2003         5
# 1997         4
# 1998         3
# 1999         3
# 1993         2
# 1994         2
# 2001         2
# 2002         2
# 1986         2
# 1992         2
# 1995         2
# 2021         2
# 2000         2
# 20120214     1
# 1990         1
# 1980         1
# Name: publish_year, dtype: int64

# %%
#all observations without a publish year
assert len(df1[df1.publish_year.isnull()]) == 0
assert len(df1[df1.publisher.isnull()]) == 0
df1[df1.binding.isnull()]
# Out:
#          isbn10         isbn13                   title          authors  \
# 461  0062300563  9780062300560         Hillbilly Elegy      J. D. Vance
# 795  1596916710  9781596916715      My Horizontal Life  Chelsea Handler
# 839  1524797154  9781524797157  Camino Island: A Novel    Grisham; John
#
#     edition binding                  publisher publish_year
# 461    None    None              Harpercollins         2016
# 795    None    None  Bloomsbury Publishing Usa         2008
# 839    None    None                       Dell         2018

# %%
df1
# Out:
#          isbn10         isbn13  \
# 0    0761148574  9780761148579
# 1    1419739034  9781419739033
# 2    0545791421  9780545791427
# 3    059035342X  9780590353427
# 4    1419727435  9781419727436
# ..          ...            ...
# 944  1492646318  9781492646310
# 945  0062101986  9780062101983
# 946  1338189611  9781338189612
# 947  078512179X  9780785121794
# 948  1595828117  9781595828118
#
#                                                  title  \
# 0                 What to Expect When You're Expecting
# 1         Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 2    Harry Potter The Illustrated 4 Books Collectio...
# 3                Harry Potter and the Sorcerer's Stone
# 4          The Meltdown (Diary of a Wimpy Kid Book 13)
# ..                                                 ...
# 944                                How to Catch an Elf
# 945                              The One and Only Ivan
# 946  The Bad Guys in Do-You-Think-He-Saurus?!: Spec...
# 947                        Civil War (2006 Marvel) #1A
# 948    Avatar: The Last Airbender: The Promise, Part 1
#
#                                                authors  \
# 0                        Murkoff, Heidi; Mazel, Sharon
# 1                                         Kinney, Jeff
# 2                                         J.K. Rowling
# 3                                        Rowling, J.K.
# 4                                         Kinney, Jeff
# ..                                                 ...
# 944                                      Wallace, Adam
# 945                               Applegate, Katherine
# 946                                      Blabey, Aaron
# 947                                        Mark Millar
# 948  Michael Dante DiMartino; Bryan Konietzko; Gene...
#
#                                       edition         binding  \
# 0                                         4th       Paperback
# 1                                 Illustrated       Hardcover
# 2                                           1       Hardcover
# 3    1st Scholastic Td Ppbk Print., Sept.1999       Paperback
# 4                                        None  Kindle Edition
# ..                                        ...             ...
# 944                               Illustrated       Hardcover
# 945                               Illustrated  Kindle Edition
# 946                               Special ed.       Paperback
# 947                                       1st           Comic
# 948                               Illustrated       Paperback
#
#                        publisher publish_year
# 0     Workman Publishing Company         2008
# 1                Harry N. Abrams         2019
# 2    Bloomsbury Children's Books         2020
# 3                     Scholastic         1998
# 4                   Amulet Books         2018
# ..                           ...          ...
# 944       Sourcebooks Wonderland         2016
# 945                HarperCollins         2012
# 946        Scholastic Paperbacks         2018
# 947                       Marvel         2022
# 948             Dark Horse Books         2012
#
# [949 rows x 8 columns]
